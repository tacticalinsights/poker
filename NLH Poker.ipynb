# %%
import random
import itertools
from IPython.display import clear_output
import time
import pandas as pd

# %% [markdown]
# # General

# %% [markdown]
# ### Card Deck Representation

# %%
ranks = ['Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace']
suits = ['Spades', 'Clubs', 'Hearts', 'Diamonds']
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
          'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace': 14}
value_to_rank = {'2': 'Two', '3': 'Three', '4': 'Four', '5': 'Five', '6': 'Six', '7': 'Seven', '8': 'Eight', 
                 '9': 'Nine', 'T': 'Ten', 'J': 'Jack', 'Q': 'Queen', 'K': 'King', 'A': 'Ace'} # for range input
possible_hands = ['royal flush', 'straight flush', 'four of a kind', 'full house', 'flush', 'straight', 'three of a kind', 'two pair', 'one pair', 'high card']

# %%
class Card:
    
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit
        self.value = values[self.rank]
    
    def __repr__(self):
        return self.rank + ' ' + self.suit
    
    def __str__(self):
        return self.rank + ' ' + self.suit

# %%
class Deck:
    
    def __init__(self, variant = 'holdem'):
        self.deck = []
        if variant == "Short Deck":
            for suit in suits:
                for rank in ranks[4:]:
                    self.deck.append(Card(rank, suit))
        else:
            for suit in suits:
                for rank in ranks:
                    self.deck.append(Card(rank, suit))
                
    def shuffle(self):
        random.shuffle(self.deck)
    
    def burn(self):
        return self.deck.pop(0)
    
    def deal(self):
        return self.deck.pop(0)
    
    def remove(self, remove_card): # remove specific card
        for card in self.deck:
            if str(card) == str(remove_card):
                self.deck.remove(card)
    
    def __str__(self):
        deck = ''
        for card in self.deck:
            deck += card.__str__() + '\n'
        return deck[:-1]

# %% [markdown]
# ### Player Representation

# %%
class Player:
    
    def __init__(self, name, chips, hole_cards, in_hand, not_acted, curr_bet, all_in):
        self.name = name
        self.chips = chips
        self.hole_cards = hole_cards
        self.in_hand = in_hand
        self.not_acted = not_acted
        self.curr_bet = curr_bet
        self.all_in = all_in
        
    def fold(self):
        self.in_hand = False
        self.curr_bet = 0
    
    def bet(self, amnt):
        self.chips -= amnt
        self.curr_bet += amnt
        
    def chip_transaction(self, amnt):
        self.chips += amnt
    
    def __repr__(self):
        return self.name
    
    def __str__(self):
        return self.name

# %%
def count_players_in_hand(players):
    count = 0
    for player in players:
        if player.in_hand:
            count += 1
    return count

# %% [markdown]
# ### Hand Strength Detection (at showdown)

# %%
def best_hand(cards, variant = 'holdem'):
    possible_hands = []
    if variant == 'Omaha':
        hole_cards = cards[:4]
        community_cards = cards[4:]
        for hand in list(itertools.combinations(cards, 5)):
            hole_hand = [card for card in hand if card in hole_cards]
            community_hand = [card for card in hand if card in community_cards]
            if len(hole_hand) == 2 and len(community_hand) == 3:
                possible_hands.append(list(hand))
    else:
        for hand in list(itertools.combinations(cards, 5)):
            possible_hands.append(list(hand))
    possible_hands.sort(key = (lambda x: x[0].value + x[1].value + x[2].value + x[3].value + x[4].value), reverse = True)
    for hand in possible_hands:
        hand.sort(key = (lambda x: x.value), reverse = True) 
    
    # royal flush and straight flush
    for hand in possible_hands:
        if hand[0].suit == hand[1].suit == hand[2].suit == hand[3].suit == hand[4].suit:
            if hand[0].rank == 'Ace' and hand[1].rank == 'King' and hand[2].rank == 'Queen' and hand[3].rank == 'Jack' and hand[4].rank == 'Ten':
                return "royal flush", [hand[0], hand[1], hand[2], hand[3], hand[4]]
            elif hand[0].value == (hand[1].value + 1) == (hand[2].value + 2) == (hand[3].value + 3) == (hand[4].value + 4):
                return "straight flush", [hand[0], hand[1], hand[2], hand[3], hand[4]]
            
    # quads
    for hand in possible_hands:
        if hand[0].rank == hand[1].rank == hand[2].rank == hand[3].rank:
            return "four of a kind", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        if hand[1].rank == hand[2].rank == hand[3].rank == hand[4].rank:
            return "four of a kind", [hand[1], hand[2], hand[3], hand[4], hand[0]]
    
    if variant == 'Short Deck': # flush beats full house in short deck
        # flush
        for hand in possible_hands:
            if hand[0].suit == hand[1].suit == hand[2].suit == hand[3].suit == hand[4].suit:
                return "flush", [hand[0], hand[1], hand[2], hand[3], hand[4]]
    
        # full house
        for hand in possible_hands:
            if (hand[0].rank == hand[1].rank) and (hand[2].rank == hand[3].rank == hand[4].rank):
                return "full house", [hand[2], hand[3], hand[3], hand[0], hand[1]]
            if (hand[0].rank == hand[1].rank == hand[2].rank) and (hand[3].rank == hand[4].rank):
                return "full house", [hand[0], hand[1], hand[2], hand[3], hand[4]]
    
    else: # full house beats flush in other variants
        # full house
        for hand in possible_hands:
            if (hand[0].rank == hand[1].rank) and (hand[2].rank == hand[3].rank == hand[4].rank):
                return "full house", [hand[2], hand[3], hand[3], hand[0], hand[1]]
            if (hand[0].rank == hand[1].rank == hand[2].rank) and (hand[3].rank == hand[4].rank):
                return "full house", [hand[0], hand[1], hand[2], hand[3], hand[4]]

        # flush
        for hand in possible_hands:
            if hand[0].suit == hand[1].suit == hand[2].suit == hand[3].suit == hand[4].suit:
                return "flush", [hand[0], hand[1], hand[2], hand[3], hand[4]]
    
    # straight
    for hand in possible_hands:
        if hand[0].value == (hand[1].value + 1) == (hand[2].value + 2) == (hand[3].value + 3) == (hand[4].value + 4):
            return "straight", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        elif hand[0].rank == 'Ace' and hand[1].rank == 'Six' and hand[2].rank == 'Seven' and hand[3].rank == 'Eight' and hand[4].rank == 'Nine':
            if variant == 'Short Deck':
                return "straight", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        elif hand[0].rank == 'Ace' and hand[1].rank == 'Five' and hand[2].rank == 'Four' and hand[3].rank == 'Three' and hand[4].rank == 'Two':
            return "straight", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        
    # trips
    for hand in possible_hands:
        if hand[0].rank == hand[1].rank == hand[2].rank:
            return "three of a kind", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        if hand[1].rank == hand[2].rank == hand[3].rank:
            return "three of a kind", [hand[1], hand[2], hand[3], hand[0], hand[4]]
        if hand[2].rank == hand[3].rank == hand[4].rank:
            return "three of a kind", [hand[2], hand[3], hand[4], hand[0], hand[1]]
        
    # two pair
    for hand in possible_hands:
        if (hand[0].rank == hand[1].rank) and (hand[2].rank == hand[3].rank):
            return "two pair", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        if (hand[0].rank == hand[1].rank) and (hand[3].rank == hand[4].rank):
            return "two pair", [hand[0], hand[1], hand[3], hand[4], hand[2]]
        if (hand[1].rank == hand[2].rank) and (hand[3].rank == hand[4].rank):
            return "two pair", [hand[1], hand[2], hand[3], hand[4], hand[0]]
        
    # one pair
    for hand in possible_hands:
        if hand[0].rank == hand[1].rank:
            return "one pair", [hand[0], hand[1], hand[2], hand[3], hand[4]]
        if hand[1].rank == hand[2].rank:
            return "one pair", [hand[1], hand[2], hand[0], hand[3], hand[4]]
        if hand[2].rank == hand[3].rank:
            return "one pair", [hand[2], hand[3], hand[0], hand[1], hand[4]]
        if hand[3].rank == hand[4].rank:
            return "one pair", [hand[3], hand[4], hand[0], hand[1], hand[2]]
        
    hand = possible_hands[0]
    return 'high card', [hand[0], hand[1], hand[2], hand[3], hand[4]]

# %% [markdown]
# ### Gameplay Functionality

# %%
def hole_cards(players, deck, variant = 'holdem'):
    num_hole_cards = 2
    if variant == 'Omaha':
        num_hole_cards = 4
    for i in range(num_hole_cards): # deal hole cards to each player
        for player in players:
            player.hole_cards.append(deck.deal())
    for player in players: # view cards
        view = input(f"Press enter to view {player.name}'s cards.")
        print(player.hole_cards)
        exit = input("Press enter to stop viewing.")
        clear_output()
        time.sleep(0.05)
    return players, deck

# %%
def betting_round(players, starting_position, curr_bet, pot, bb):
    
    i = starting_position # index of first player to act
    
    betting = True
    while betting:
        
        player = players[i]
        
        # player action
        if player.in_hand and player.not_acted and not player.all_in:
            invalid_action = True
            while invalid_action:
                
                print(f"{player.name} Action: ")
                move = input("Enter one of 'fold' / 'check' / 'call' / 'raise' / 'all-in': ")
                
                # fold
                if move[0] == 'f':
                    invalid_action = False
                    player.fold()
                    player.not_acted = False
                
                # check and call
                elif move[0] == 'c':    
                    if move[1] == 'h': # check
                        if player.curr_bet == curr_bet:
                            invalid_action = False
                            player.not_acted = False
                        else:
                            print("Invalid Action; You must match current bet or fold.") 
                    else: # call
                        if player.curr_bet < curr_bet and player.chips >= (curr_bet - player.curr_bet):
                            invalid_action = False
                            pot += (curr_bet - player.curr_bet)
                            player.bet(curr_bet - player.curr_bet)
                            player.not_acted = False
                        elif player.curr_bet < curr_bet and player.chips < (curr_bet - player.curr_bet):
                            move = 'all in' # if insufficient chips to call, player shoves
                        else: # if player calls when no one has bet, player checks
                            invalid_action = False
                            player.not_acted = False
                            
                # raise
                elif move[0] == 'r':
                    if curr_bet > 0 and player.chips <= (2*curr_bet):
                        move = 'a'
                    elif curr_bet == 0 and player.chips <= bb:
                        move = 'a'
                    else:
                        invalid_action = False
                        invalid_raise = True
                        while invalid_raise:
                            amnt = int(input('Enter total number of chips to bet(includes current bet): '))
                            if curr_bet > 0:
                                if amnt >= (2*curr_bet):
                                    invalid_raise = False
                                    pot += (amnt - player.curr_bet)
                                    player.bet(amnt - player.curr_bet)
                                    curr_bet = amnt
                                    player.not_acted = False
                                    for player in players:
                                        if player.in_hand and player != players[i] and not(player.all_in):
                                            player.not_acted = True 
                                else:
                                    print('Invalid Raise Amount; You must at least double current bet.')
                            else:
                                if amnt >= bb:
                                    invalid_raise = False
                                    pot += (amnt - player.curr_bet)
                                    player.bet(amnt)
                                    curr_bet = amnt
                                    player.not_acted = False
                                    for player in players:
                                        if player.in_hand and player != players[i] and not(player.all_in):
                                            player.not_acted = True        
                                else:
                                    print('Invalid Raise Amount; Your bet must be greater than or equal to big blind.')
                
                elif move[0] != 'a':
                    print('Invalid Action')
                
                if move[0] == 'a': # all in
                    invalid_action = False
                    curr_bet_updated = False
                    if (player.chips + player.curr_bet) > curr_bet:
                        curr_bet = player.chips + player.curr_bet
                        curr_bet_updated = True
                    pot += player.chips
                    player.bet(player.chips)
                    player.all_in = True
                    player.not_acted = False
                    if curr_bet_updated:
                        for player in players:
                            if player.in_hand and player != players[i] and not(player.all_in):
                                player.not_acted = True
        
        # after each action, check if betting is finished
        betting = False
        if count_players_in_hand(players) > 1:
            for player in players:
                if player.not_acted: # CONTINUE FROM HERE
                    betting = True
                    break
        
        # move to next player
        if players[i] == players[-1]:
            i = 0
        else:
            i += 1
        
    clear_output()
    time.sleep(0.05)
        
    return players, pot

# %%
def community_cards(cards, num, deck, pot):
    deck.burn()
    for i in range(num):
        cards.append(deck.deal())
    print(cards)
    print(f"Pot: {pot}\n")
    return cards, deck

# %%
def reset_curr_bets(players):
    count = 0
    for player in players:
        if player.in_hand and not player.all_in:
            count += 1
    if count == 1:
        return players
    for player in players:
        if player.in_hand:
            player.not_acted = True
            player.curr_bet = 0
    return players

# %%
def detect_winner(round_, players, pot): # if everyone has folded, declare last man standing as winner
    if count_players_in_hand(players) == 1:
        round_ = False
        for player in players:
            if player.in_hand:
                print(player.name + " wins " + str(pot) + " chips.")
                player.chip_transaction(pot)
    return round_, players

# %%
def showdown_winner(players, river, pot, variant):
    if count_players_in_hand(players) != 1:
        hands = {}
        for player in players:
            if player.in_hand:
                cards = player.hole_cards + river
                value_lst = [] # convert list of card to list of values of cards
                for card in best_hand(cards, variant)[1]:
                    value_lst.append(card.value)
                hands[player] = ((best_hand(cards, variant)[0], value_lst, best_hand(cards, variant)[1]), possible_hands.index(best_hand(cards, variant)[0]))
        best = min(hands.items(), key = (lambda x: x[1][1]))[1][1]
        for player in hands.keys():
            if hands[player][1] != best:
                hands[player] = (('0', [0, 0, 0, 0, 0]), 10) # effectively deletes this player
        
        # finding best kicker (sorted by value_lst)
        winner = sorted(hands.items(), key = (lambda x: x[1][0][1]), reverse = True)[0][0]

        # reporting winner
        print(f"{winner.name} hole cards are {winner.hole_cards}.")
        print(f"Community cards are {river}.\n")
        print(f"{winner.name}'s hand: {hands[winner][0][2]}")
        print(winner.name + " wins " + str(pot) + " chips with " + hands[winner][0][0])
        winner.chip_transaction(pot)
        
    return players

# %%
def play_again(players, game):
    for player in players:
        if player.chips == 0:
            players.remove(player)
    if len(players) == 1:
        print(f"\n{players[0].name} Wins With {players[0].chips}!")
        print("Thanks for playing!")
        return players, False
    again = input("\nDo you want to play again?")
    if again.lower()[0] == 'y':
        game = True
        players = players[1:] + [players[0]] # position progression
        for player in players: # reset
            player.hole_cards = []
            player.in_hand = True
            player.not_acted = True
            player.curr_bet = 0
            player.all_in = False
        clear_output()
        time.sleep(0.05)
    else:
        game = False
        clear_output()
        time.sleep(0.1)
        for player in players:
            print(f"{player.name}: {player.chips}")
        print("Thanks for playing!")
    return players, game

# %% [markdown]
# ### Textual Interface for Game

# %%
variant = ''
while variant not in ['holdem', 'Omaha', 'Short Deck']:
    print('You can choose to play one of the following three poker variants: holdem, Omaha, Short Deck')
    variant = input("Which poker variant would you like to play?: ")
sb = int(input("Choose small blind amount (enter a number): "))
bb = sb*2
stack = int(input("Choose starting stack amount (enter a number): "))
num_players = int(input("How many players? (enter a number): "))
heads_up = False
if num_players == 2:
    heads_up = True

players = []
for player in range(num_players):
    name = input(f"Enter player {player}'s name: ")
    players.append(Player(name, stack, [], True, True, 0, False))
random.shuffle(players)

game = True
while game:
    
    round_ = True
    
    # positions
    print("Order of Action: ")
    for player in players:
        print(f"{player.name}: {player.chips}")
    continue_prompt = input("Press enter to continue: ")
    clear_output()
    time.sleep(0.05)
    
    # pre-flop
    if round_:
        deck = Deck(variant) # new deck
        deck.shuffle() # shuffle deck
        players, deck = hole_cards(players, deck, variant) # deal hole cards
        players[0].bet(sb) # small blind posted
        players[1].bet(bb) # big blind posted
        if heads_up:
            players, pot = betting_round(players, 0, bb, (sb + bb), bb) # round of betting
        else:
            players, pot = betting_round(players, 2, bb, (sb + bb), bb) # round of betting
        round_, players = detect_winner(round_, players, pot) # detects winner before showdown

    # flop
    if round_:
        flop, deck = community_cards([], 3, deck, pot) # deal flop
        players = reset_curr_bets(players) # reset current bets
        if heads_up:
            players, pot = betting_round(players, 1, 0, pot, bb) # round of betting
            print(players)
        else:
            players, pot = betting_round(players, 0, 0, pot, bb) # round of betting
        round_, players = detect_winner(round_, players, pot) # detects winner before showdown

    # turn
    if round_:
        turn, deck = community_cards(flop, 1, deck, pot) # deal turn
        players = reset_curr_bets(players) # reset current bets
        if heads_up:
            players, pot = betting_round(players, 1, 0, pot, bb) # round of betting
            print(players)
        else:
            players, pot = betting_round(players, 0, 0, pot, bb) # round of betting
        round_, players = detect_winner(round_, players, pot) # detects winner before showdown

    # river
    if round_:
        river, deck = community_cards(turn, 1, deck, pot) # deal river
        players = reset_curr_bets(players) # reset current bets
        if heads_up:
            players, pot = betting_round(players, 1, 0, pot, bb) # round of betting
        else:
            players, pot = betting_round(players, 0, 0, pot, bb) # round of betting
        round_, players = detect_winner(round_, players, pot) # detects winner before showdown
        players = showdown_winner(players, river, pot, variant) # determine best hand at showdown
    
    players, game = play_again(players, game) # another round
# Out:
# a hole cards are [Ten Spades, Five Spades].
# Community cards are [Jack Hearts, Three Diamonds, Three Spades, Seven Diamonds, Eight Diamonds].
#
# a's hand: [Three Diamonds, Three Spades, Jack Hearts, Ten Spades, Eight Diamonds]
# a wins 400 chips with one pair
#
# a Wins With 400!
# Thanks for playing!

# %% [markdown]
# # Simulations

# %% [markdown]
# ### Showdown Hand Probabilities

# %%
def showdown_hand_probability(num_iters, var):
    num_cards_in_hand = 7
    if var == 'Omaha':
        num_cards_in_hand = 9
    hand_history = []
    for x in range(num_iters):
        deck = Deck(variant = var)
        deck.shuffle()
        hand = []
        for x in range(num_cards_in_hand):
            hand.append(deck.deal())
        hand.sort(key = (lambda x: values[x.rank]), reverse = True)
        hand_history.append(best_hand(hand, variant = var)[0])
        
    probabilities = {'high card': hand_history.count('high card')/num_iters,
                     'one pair': hand_history.count('one pair')/num_iters, 
                     'two pair': hand_history.count('two pair')/num_iters, 
                     'three of a kind': hand_history.count('three of a kind')/num_iters, 
                     'straight': hand_history.count('straight')/num_iters,
                     'flush': hand_history.count('flush')/num_iters,
                     'full house': hand_history.count('full house')/num_iters,
                     'four of a kind': hand_history.count('four of a kind')/num_iters,
                     'straight flush': hand_history.count('straight flush')/num_iters,
                     'royal flush': hand_history.count('royal flush')/num_iters}
    return probabilities

# %%
num_iters = 1000000
holdem_probs = showdown_hand_probability(num_iters, 'holdem')
omaha_probs = showdown_hand_probability(num_iters, 'Omaha')
short_deck_probs = showdown_hand_probability(num_iters, 'Short Deck')

# %%
df = pd.DataFrame(index = possible_hands[::-1])
df['holdem'] = holdem_probs.values()
df['Omaha'] = omaha_probs.values()
df['Short Deck'] = short_deck_probs.values()
df.to_csv('poker_showdown_hand_probabilities.csv')

# %% [markdown]
# # Equity Calculator
#
# Supports Hand vs Hand, Hand vs Range, and Range vs Range equity calculations, both pre-flop and post-flop

# %%
def hand_comparison(players, community_cards, var = 'holdem'):
    hands = {}
    for player in players:
        cards = player.hole_cards + community_cards
        value_lst = [] # convert list of card to list of values of cards
        for card in best_hand(cards, var)[1]:
            value_lst.append(card.value)
        hands[player] = ((best_hand(cards, var)[0], value_lst, best_hand(cards, var)[1]), possible_hands.index(best_hand(cards, var)[0]))
    best = min(hands.items(), key = (lambda x: x[1][1]))[1][1]
    for player in hands.keys():
        if hands[player][1] != best:
            hands[player] = (('0', [0, 0, 0, 0, 0]), 10) # effectively deletes this player
    winner = sorted(hands.items(), key = (lambda x: x[1][0][1]), reverse = True)[0][0] # finding best kicker
    return winner.name

# %%
def equity_calculator(r1, r2, cc = [], var = 'holdem', num_iters = 10000): # range vs range equity
    p1 = Player('p1', 0, [], True, True, 0, False)
    p2 = Player('p2', 0, [], True, True, 0, False)
    players = [p1, p2]
    p1_wins = 0
    for i in range(num_iters):
        p1.hole_cards = random.choice(r1) # r1 is list of lists (each element list is a hand)
        p2.hole_cards = random.choice(r2)
        deck = Deck(variant = var)
        community_cards = []
        for card in cc:
            community_cards.append(card)
        for card in p1.hole_cards:
            deck.remove(card)
        for card in p2.hole_cards:
            deck.remove(card)
        for card in community_cards:
            deck.remove(card)
        deck.shuffle()
        while(len(community_cards) != 5):
            community_cards.append(deck.deal())
        if hand_comparison(players, community_cards, var) == 'p1':
            p1_wins += 1
    print(f"Range 1: {round(p1_wins/num_iters * 100, 3)}%")
    print(f"Range 2: {round((1 - p1_wins/num_iters) * 100, 3)}%")
    return [(r1, round(p1_wins/num_iters * 100, 3)), (r2, round((1 - p1_wins/num_iters) * 100, 3))]

# %% [markdown]
# ### Choosing Custom Hand Ranges

# %%
def pick_range(t = ''): # only for holdem
    range_ = []
    if t == '':
        r = input("Enter your range in standard format: ")
    else:
        r = t
    hands = r.split(',')
    count = 0
    for h in hands:
        if len(h) == 2: # pocket pair
            suit_combinations = list(itertools.combinations(suits, 2))
            for suit0, suit1 in suit_combinations:
                range_.append([Card(value_to_rank[h[0]], suit0), Card(value_to_rank[h[1]], suit1)])
                count += 1
        elif h[2] == 's': # suited
            for suit in suits:
                range_.append([Card(value_to_rank[h[0]], suit), Card(value_to_rank[h[1]], suit)])
                count += 1
        else: # off-suit
            suit_permutations = list(itertools.permutations(suits, 2))
            for suit0, suit1 in suit_permutations:
                range_.append([Card(value_to_rank[h[0]], suit0), Card(value_to_rank[h[1]], suit1)])
                count += 1
    # print(count, '\n')
    return range_

# %% [markdown]
# ### Game Theory Optimal Button RFI Range for Heads Up NLH

# %%
def button_rfi():
    t = ''
    input_list = list(value_to_rank.keys())[::-1]
    for i in input_list:
        for j in input_list:
            if input_list.index(j) < input_list.index(i):
                continue
            t += i
            t += j
            if i == j:
                t += ','
            else:
                t += 's,'
    for i in ['A', 'K']:
        for j in input_list:
            if input_list.index(j) <= input_list.index(i):
                continue
            t += i
            t += j
            t += 'o,'
    for i in ['5', '4']:
        for j in input_list[:-1]:
            if input_list.index(j) <= input_list.index(i):
                continue
            t += i
            t += j
            t += 'o,'
    for i in ['Q', '7', '6']:
        for j in input_list[:-2]:
            if input_list.index(j) <= input_list.index(i):
                continue
            t += i
            t += j
            t += 'o,'
    for i in ['J', 'T', '9', '8']:
        for j in input_list[:-3]:
            if input_list.index(j) <= input_list.index(i):
                continue
            t += i
            t += j
            t += 'o,'
    t = t[:-1]
    return t

# %% [markdown]
# ### Demonstrated Usage of Equity Calculator

# %%
# Using a custom range
# Instructions:
    # Input a number or letter from 2 to 9 or T (ten) to A (ace) for the first card in your hand. 
    # Input another number or letter in a similar format for the second card in your hand.
    # If your hand is a pocket pair, you are done. If not input o or s for off-suit or suited.
    # To input another card in your range, input a comma and then repeat. NO SPACES.
    
r1 = pick_range()
r2 = pick_range()
# Out:
# Enter your range in standard format: 65s
# Enter your range in standard format: AA

# %%
# Using a default range
r1 = pick_range(button_rfi())
r2 = [[Card('Ace', 'Spades'), Card('Ace', 'Clubs')]]

# %%
lst = equity_calculator(r1, r2, [], 'holdem', 100000)
# Out:
# Range 1: 15.395%
# Range 2: 84.605%

# %%
lst
# Out:
# [([[Ace Spades, Ace Clubs],
#    [Ace Spades, Ace Hearts],
#    [Ace Spades, Ace Diamonds],
#    [Ace Clubs, Ace Hearts],
#    [Ace Clubs, Ace Diamonds],
#    [Ace Hearts, Ace Diamonds],
#    [Ace Spades, King Spades],
#    [Ace Clubs, King Clubs],
#    [Ace Hearts, King Hearts],
#    [Ace Diamonds, King Diamonds],
#    [Ace Spades, Queen Spades],
#    [Ace Clubs, Queen Clubs],
#    [Ace Hearts, Queen Hearts],
#    [Ace Diamonds, Queen Diamonds],
#    [Ace Spades, Jack Spades],
#    [Ace Clubs, Jack Clubs],
#    [Ace Hearts, Jack Hearts],
#    [Ace Diamonds, Jack Diamonds],
#    [Ace Spades, Ten Spades],
#    [Ace Clubs, Ten Clubs],
#    [Ace Hearts, Ten Hearts],
#    [Ace Diamonds, Ten Diamonds],
#    [Ace Spades, Nine Spades],
#    [Ace Clubs, Nine Clubs],
#    [Ace Hearts, Nine Hearts],
#    [Ace Diamonds, Nine Diamonds],
#    [Ace Spades, Eight Spades],
#    [Ace Clubs, Eight Clubs],
#    [Ace Hearts, Eight Hearts],
#    [Ace Diamonds, Eight Diamonds],
#    [Ace Spades, Seven Spades],
#    [Ace Clubs, Seven Clubs],
#    [Ace Hearts, Seven Hearts],
#    [Ace Diamonds, Seven Diamonds],
#    [Ace Spades, Six Spades],
#    [Ace Clubs, Six Clubs],
#    [Ace Hearts, Six Hearts],
#    [Ace Diamonds, Six Diamonds],
#    [Ace Spades, Five Spades],
#    [Ace Clubs, Five Clubs],
#    [Ace Hearts, Five Hearts],
#    [Ace Diamonds, Five Diamonds],
#    [Ace Spades, Four Spades],
#    [Ace Clubs, Four Clubs],
#    [Ace Hearts, Four Hearts],
#    [Ace Diamonds, Four Diamonds],
#    [Ace Spades, Three Spades],
#    [Ace Clubs, Three Clubs],
#    [Ace Hearts, Three Hearts],
#    [Ace Diamonds, Three Diamonds],
#    [Ace Spades, Two Spades],
#    [Ace Clubs, Two Clubs],
#    [Ace Hearts, Two Hearts],
#    [Ace Diamonds, Two Diamonds],
#    [King Spades, King Clubs],
#    [King Spades, King Hearts],
#    [King Spades, King Diamonds],
#    [King Clubs, King Hearts],
#    [King Clubs, King Diamonds],
#    [King Hearts, King Diamonds],
#    [King Spades, Queen Spades],
#    [King Clubs, Queen Clubs],
#    [King Hearts, Queen Hearts],
#    [King Diamonds, Queen Diamonds],
#    [King Spades, Jack Spades],
#    [King Clubs, Jack Clubs],
#    [King Hearts, Jack Hearts],
#    [King Diamonds, Jack Diamonds],
#    [King Spades, Ten Spades],
#    [King Clubs, Ten Clubs],
#    [King Hearts, Ten Hearts],
#    [King Diamonds, Ten Diamonds],
#    [King Spades, Nine Spades],
#    [King Clubs, Nine Clubs],
#    [King Hearts, Nine Hearts],
#    [King Diamonds, Nine Diamonds],
#    [King Spades, Eight Spades],
#    [King Clubs, Eight Clubs],
#    [King Hearts, Eight Hearts],
#    [King Diamonds, Eight Diamonds],
#    [King Spades, Seven Spades],
#    [King Clubs, Seven Clubs],
#    [King Hearts, Seven Hearts],
#    [King Diamonds, Seven Diamonds],
#    [King Spades, Six Spades],
#    [King Clubs, Six Clubs],
#    [King Hearts, Six Hearts],
#    [King Diamonds, Six Diamonds],
#    [King Spades, Five Spades],
#    [King Clubs, Five Clubs],
#    [King Hearts, Five Hearts],
#    [King Diamonds, Five Diamonds],
#    [King Spades, Four Spades],
#    [King Clubs, Four Clubs],
#    [King Hearts, Four Hearts],
#    [King Diamonds, Four Diamonds],
#    [King Spades, Three Spades],
#    [King Clubs, Three Clubs],
#    [King Hearts, Three Hearts],
#    [King Diamonds, Three Diamonds],
#    [King Spades, Two Spades],
#    [King Clubs, Two Clubs],
#    [King Hearts, Two Hearts],
#    [King Diamonds, Two Diamonds],
#    [Queen Spades, Queen Clubs],
#    [Queen Spades, Queen Hearts],
#    [Queen Spades, Queen Diamonds],
#    [Queen Clubs, Queen Hearts],
#    [Queen Clubs, Queen Diamonds],
#    [Queen Hearts, Queen Diamonds],
#    [Queen Spades, Jack Spades],
#    [Queen Clubs, Jack Clubs],
#    [Queen Hearts, Jack Hearts],
#    [Queen Diamonds, Jack Diamonds],
#    [Queen Spades, Ten Spades],
#    [Queen Clubs, Ten Clubs],
#    [Queen Hearts, Ten Hearts],
#    [Queen Diamonds, Ten Diamonds],
#    [Queen Spades, Nine Spades],
#    [Queen Clubs, Nine Clubs],
#    [Queen Hearts, Nine Hearts],
#    [Queen Diamonds, Nine Diamonds],
#    [Queen Spades, Eight Spades],
#    [Queen Clubs, Eight Clubs],
#    [Queen Hearts, Eight Hearts],
#    [Queen Diamonds, Eight Diamonds],
#    [Queen Spades, Seven Spades],
#    [Queen Clubs, Seven Clubs],
#    [Queen Hearts, Seven Hearts],
#    [Queen Diamonds, Seven Diamonds],
#    [Queen Spades, Six Spades],
#    [Queen Clubs, Six Clubs],
#    [Queen Hearts, Six Hearts],
#    [Queen Diamonds, Six Diamonds],
#    [Queen Spades, Five Spades],
#    [Queen Clubs, Five Clubs],
#    [Queen Hearts, Five Hearts],
#    [Queen Diamonds, Five Diamonds],
#    [Queen Spades, Four Spades],
#    [Queen Clubs, Four Clubs],
#    [Queen Hearts, Four Hearts],
#    [Queen Diamonds, Four Diamonds],
#    [Queen Spades, Three Spades],
#    [Queen Clubs, Three Clubs],
#    [Queen Hearts, Three Hearts],
#    [Queen Diamonds, Three Diamonds],
#    [Queen Spades, Two Spades],
#    [Queen Clubs, Two Clubs],
#    [Queen Hearts, Two Hearts],
#    [Queen Diamonds, Two Diamonds],
#    [Jack Spades, Jack Clubs],
#    [Jack Spades, Jack Hearts],
#    [Jack Spades, Jack Diamonds],
#    [Jack Clubs, Jack Hearts],
#    [Jack Clubs, Jack Diamonds],
#    [Jack Hearts, Jack Diamonds],
#    [Jack Spades, Ten Spades],
#    [Jack Clubs, Ten Clubs],
#    [Jack Hearts, Ten Hearts],
#    [Jack Diamonds, Ten Diamonds],
#    [Jack Spades, Nine Spades],
#    [Jack Clubs, Nine Clubs],
#    [Jack Hearts, Nine Hearts],
#    [Jack Diamonds, Nine Diamonds],
#    [Jack Spades, Eight Spades],
#    [Jack Clubs, Eight Clubs],
#    [Jack Hearts, Eight Hearts],
#    [Jack Diamonds, Eight Diamonds],
#    [Jack Spades, Seven Spades],
#    [Jack Clubs, Seven Clubs],
#    [Jack Hearts, Seven Hearts],
#    [Jack Diamonds, Seven Diamonds],
#    [Jack Spades, Six Spades],
#    [Jack Clubs, Six Clubs],
#    [Jack Hearts, Six Hearts],
#    [Jack Diamonds, Six Diamonds],
#    [Jack Spades, Five Spades],
#    [Jack Clubs, Five Clubs],
#    [Jack Hearts, Five Hearts],
#    [Jack Diamonds, Five Diamonds],
#    [Jack Spades, Four Spades],
#    [Jack Clubs, Four Clubs],
#    [Jack Hearts, Four Hearts],
#    [Jack Diamonds, Four Diamonds],
#    [Jack Spades, Three Spades],
#    [Jack Clubs, Three Clubs],
#    [Jack Hearts, Three Hearts],
#    [Jack Diamonds, Three Diamonds],
#    [Jack Spades, Two Spades],
#    [Jack Clubs, Two Clubs],
#    [Jack Hearts, Two Hearts],
#    [Jack Diamonds, Two Diamonds],
#    [Ten Spades, Ten Clubs],
#    [Ten Spades, Ten Hearts],
#    [Ten Spades, Ten Diamonds],
#    [Ten Clubs, Ten Hearts],
#    [Ten Clubs, Ten Diamonds],
#    [Ten Hearts, Ten Diamonds],
#    [Ten Spades, Nine Spades],
#    [Ten Clubs, Nine Clubs],
#    [Ten Hearts, Nine Hearts],
#    [Ten Diamonds, Nine Diamonds],
#    [Ten Spades, Eight Spades],
#    [Ten Clubs, Eight Clubs],
#    [Ten Hearts, Eight Hearts],
#    [Ten Diamonds, Eight Diamonds],
#    [Ten Spades, Seven Spades],
#    [Ten Clubs, Seven Clubs],
#    [Ten Hearts, Seven Hearts],
#    [Ten Diamonds, Seven Diamonds],
#    [Ten Spades, Six Spades],
#    [Ten Clubs, Six Clubs],
#    [Ten Hearts, Six Hearts],
#    [Ten Diamonds, Six Diamonds],
#    [Ten Spades, Five Spades],
#    [Ten Clubs, Five Clubs],
#    [Ten Hearts, Five Hearts],
#    [Ten Diamonds, Five Diamonds],
#    [Ten Spades, Four Spades],
#    [Ten Clubs, Four Clubs],
#    [Ten Hearts, Four Hearts],
#    [Ten Diamonds, Four Diamonds],
#    [Ten Spades, Three Spades],
#    [Ten Clubs, Three Clubs],
#    [Ten Hearts, Three Hearts],
#    [Ten Diamonds, Three Diamonds],
#    [Ten Spades, Two Spades],
#    [Ten Clubs, Two Clubs],
#    [Ten Hearts, Two Hearts],
#    [Ten Diamonds, Two Diamonds],
#    [Nine Spades, Nine Clubs],
#    [Nine Spades, Nine Hearts],
#    [Nine Spades, Nine Diamonds],
#    [Nine Clubs, Nine Hearts],
#    [Nine Clubs, Nine Diamonds],
#    [Nine Hearts, Nine Diamonds],
#    [Nine Spades, Eight Spades],
#    [Nine Clubs, Eight Clubs],
#    [Nine Hearts, Eight Hearts],
#    [Nine Diamonds, Eight Diamonds],
#    [Nine Spades, Seven Spades],
#    [Nine Clubs, Seven Clubs],
#    [Nine Hearts, Seven Hearts],
#    [Nine Diamonds, Seven Diamonds],
#    [Nine Spades, Six Spades],
#    [Nine Clubs, Six Clubs],
#    [Nine Hearts, Six Hearts],
#    [Nine Diamonds, Six Diamonds],
#    [Nine Spades, Five Spades],
#    [Nine Clubs, Five Clubs],
#    [Nine Hearts, Five Hearts],
#    [Nine Diamonds, Five Diamonds],
#    [Nine Spades, Four Spades],
#    [Nine Clubs, Four Clubs],
#    [Nine Hearts, Four Hearts],
#    [Nine Diamonds, Four Diamonds],
#    [Nine Spades, Three Spades],
#    [Nine Clubs, Three Clubs],
#    [Nine Hearts, Three Hearts],
#    [Nine Diamonds, Three Diamonds],
#    [Nine Spades, Two Spades],
#    [Nine Clubs, Two Clubs],
#    [Nine Hearts, Two Hearts],
#    [Nine Diamonds, Two Diamonds],
#    [Eight Spades, Eight Clubs],
#    [Eight Spades, Eight Hearts],
#    [Eight Spades, Eight Diamonds],
#    [Eight Clubs, Eight Hearts],
#    [Eight Clubs, Eight Diamonds],
#    [Eight Hearts, Eight Diamonds],
#    [Eight Spades, Seven Spades],
#    [Eight Clubs, Seven Clubs],
#    [Eight Hearts, Seven Hearts],
#    [Eight Diamonds, Seven Diamonds],
#    [Eight Spades, Six Spades],
#    [Eight Clubs, Six Clubs],
#    [Eight Hearts, Six Hearts],
#    [Eight Diamonds, Six Diamonds],
#    [Eight Spades, Five Spades],
#    [Eight Clubs, Five Clubs],
#    [Eight Hearts, Five Hearts],
#    [Eight Diamonds, Five Diamonds],
#    [Eight Spades, Four Spades],
#    [Eight Clubs, Four Clubs],
#    [Eight Hearts, Four Hearts],
#    [Eight Diamonds, Four Diamonds],
#    [Eight Spades, Three Spades],
#    [Eight Clubs, Three Clubs],
#    [Eight Hearts, Three Hearts],
#    [Eight Diamonds, Three Diamonds],
#    [Eight Spades, Two Spades],
#    [Eight Clubs, Two Clubs],
#    [Eight Hearts, Two Hearts],
#    [Eight Diamonds, Two Diamonds],
#    [Seven Spades, Seven Clubs],
#    [Seven Spades, Seven Hearts],
#    [Seven Spades, Seven Diamonds],
#    [Seven Clubs, Seven Hearts],
#    [Seven Clubs, Seven Diamonds],
#    [Seven Hearts, Seven Diamonds],
#    [Seven Spades, Six Spades],
#    [Seven Clubs, Six Clubs],
#    [Seven Hearts, Six Hearts],
#    [Seven Diamonds, Six Diamonds],
#    [Seven Spades, Five Spades],
#    [Seven Clubs, Five Clubs],
#    [Seven Hearts, Five Hearts],
#    [Seven Diamonds, Five Diamonds],
#    [Seven Spades, Four Spades],
#    [Seven Clubs, Four Clubs],
#    [Seven Hearts, Four Hearts],
#    [Seven Diamonds, Four Diamonds],
#    [Seven Spades, Three Spades],
#    [Seven Clubs, Three Clubs],
#    [Seven Hearts, Three Hearts],
#    [Seven Diamonds, Three Diamonds],
#    [Seven Spades, Two Spades],
#    [Seven Clubs, Two Clubs],
#    [Seven Hearts, Two Hearts],
#    [Seven Diamonds, Two Diamonds],
#    [Six Spades, Six Clubs],
#    [Six Spades, Six Hearts],
#    [Six Spades, Six Diamonds],
#    [Six Clubs, Six Hearts],
#    [Six Clubs, Six Diamonds],
#    [Six Hearts, Six Diamonds],
#    [Six Spades, Five Spades],
#    [Six Clubs, Five Clubs],
#    [Six Hearts, Five Hearts],
#    [Six Diamonds, Five Diamonds],
#    [Six Spades, Four Spades],
#    [Six Clubs, Four Clubs],
#    [Six Hearts, Four Hearts],
#    [Six Diamonds, Four Diamonds],
#    [Six Spades, Three Spades],
#    [Six Clubs, Three Clubs],
#    [Six Hearts, Three Hearts],
#    [Six Diamonds, Three Diamonds],
#    [Six Spades, Two Spades],
#    [Six Clubs, Two Clubs],
#    [Six Hearts, Two Hearts],
#    [Six Diamonds, Two Diamonds],
#    [Five Spades, Five Clubs],
#    [Five Spades, Five Hearts],
#    [Five Spades, Five Diamonds],
#    [Five Clubs, Five Hearts],
#    [Five Clubs, Five Diamonds],
#    [Five Hearts, Five Diamonds],
#    [Five Spades, Four Spades],
#    [Five Clubs, Four Clubs],
#    [Five Hearts, Four Hearts],
#    [Five Diamonds, Four Diamonds],
#    [Five Spades, Three Spades],
#    [Five Clubs, Three Clubs],
#    [Five Hearts, Three Hearts],
#    [Five Diamonds, Three Diamonds],
#    [Five Spades, Two Spades],
#    [Five Clubs, Two Clubs],
#    [Five Hearts, Two Hearts],
#    [Five Diamonds, Two Diamonds],
#    [Four Spades, Four Clubs],
#    [Four Spades, Four Hearts],
#    [Four Spades, Four Diamonds],
#    [Four Clubs, Four Hearts],
#    [Four Clubs, Four Diamonds],
#    [Four Hearts, Four Diamonds],
#    [Four Spades, Three Spades],
#    [Four Clubs, Three Clubs],
#    [Four Hearts, Three Hearts],
#    [Four Diamonds, Three Diamonds],
#    [Four Spades, Two Spades],
#    [Four Clubs, Two Clubs],
#    [Four Hearts, Two Hearts],
#    [Four Diamonds, Two Diamonds],
#    [Three Spades, Three Clubs],
#    [Three Spades, Three Hearts],
#    [Three Spades, Three Diamonds],
#    [Three Clubs, Three Hearts],
#    [Three Clubs, Three Diamonds],
#    [Three Hearts, Three Diamonds],
#    [Three Spades, Two Spades],
#    [Three Clubs, Two Clubs],
#    [Three Hearts, Two Hearts],
#    [Three Diamonds, Two Diamonds],
#    [Two Spades, Two Clubs],
#    [Two Spades, Two Hearts],
#    [Two Spades, Two Diamonds],
#    [Two Clubs, Two Hearts],
#    [Two Clubs, Two Diamonds],
#    [Two Hearts, Two Diamonds],
#    [Ace Spades, King Clubs],
#    [Ace Spades, King Hearts],
#    [Ace Spades, King Diamonds],
#    [Ace Clubs, King Spades],
#    [Ace Clubs, King Hearts],
#    [Ace Clubs, King Diamonds],
#    [Ace Hearts, King Spades],
#    [Ace Hearts, King Clubs],
#    [Ace Hearts, King Diamonds],
#    [Ace Diamonds, King Spades],
#    [Ace Diamonds, King Clubs],
#    [Ace Diamonds, King Hearts],
#    [Ace Spades, Queen Clubs],
#    [Ace Spades, Queen Hearts],
#    [Ace Spades, Queen Diamonds],
#    [Ace Clubs, Queen Spades],
#    [Ace Clubs, Queen Hearts],
#    [Ace Clubs, Queen Diamonds],
#    [Ace Hearts, Queen Spades],
#    [Ace Hearts, Queen Clubs],
#    [Ace Hearts, Queen Diamonds],
#    [Ace Diamonds, Queen Spades],
#    [Ace Diamonds, Queen Clubs],
#    [Ace Diamonds, Queen Hearts],
#    [Ace Spades, Jack Clubs],
#    [Ace Spades, Jack Hearts],
#    [Ace Spades, Jack Diamonds],
#    [Ace Clubs, Jack Spades],
#    [Ace Clubs, Jack Hearts],
#    [Ace Clubs, Jack Diamonds],
#    [Ace Hearts, Jack Spades],
#    [Ace Hearts, Jack Clubs],
#    [Ace Hearts, Jack Diamonds],
#    [Ace Diamonds, Jack Spades],
#    [Ace Diamonds, Jack Clubs],
#    [Ace Diamonds, Jack Hearts],
#    [Ace Spades, Ten Clubs],
#    [Ace Spades, Ten Hearts],
#    [Ace Spades, Ten Diamonds],
#    [Ace Clubs, Ten Spades],
#    [Ace Clubs, Ten Hearts],
#    [Ace Clubs, Ten Diamonds],
#    [Ace Hearts, Ten Spades],
#    [Ace Hearts, Ten Clubs],
#    [Ace Hearts, Ten Diamonds],
#    [Ace Diamonds, Ten Spades],
#    [Ace Diamonds, Ten Clubs],
#    [Ace Diamonds, Ten Hearts],
#    [Ace Spades, Nine Clubs],
#    [Ace Spades, Nine Hearts],
#    [Ace Spades, Nine Diamonds],
#    [Ace Clubs, Nine Spades],
#    [Ace Clubs, Nine Hearts],
#    [Ace Clubs, Nine Diamonds],
#    [Ace Hearts, Nine Spades],
#    [Ace Hearts, Nine Clubs],
#    [Ace Hearts, Nine Diamonds],
#    [Ace Diamonds, Nine Spades],
#    [Ace Diamonds, Nine Clubs],
#    [Ace Diamonds, Nine Hearts],
#    [Ace Spades, Eight Clubs],
#    [Ace Spades, Eight Hearts],
#    [Ace Spades, Eight Diamonds],
#    [Ace Clubs, Eight Spades],
#    [Ace Clubs, Eight Hearts],
#    [Ace Clubs, Eight Diamonds],
#    [Ace Hearts, Eight Spades],
#    [Ace Hearts, Eight Clubs],
#    [Ace Hearts, Eight Diamonds],
#    [Ace Diamonds, Eight Spades],
#    [Ace Diamonds, Eight Clubs],
#    [Ace Diamonds, Eight Hearts],
#    [Ace Spades, Seven Clubs],
#    [Ace Spades, Seven Hearts],
#    [Ace Spades, Seven Diamonds],
#    [Ace Clubs, Seven Spades],
#    [Ace Clubs, Seven Hearts],
#    [Ace Clubs, Seven Diamonds],
#    [Ace Hearts, Seven Spades],
#    [Ace Hearts, Seven Clubs],
#    [Ace Hearts, Seven Diamonds],
#    [Ace Diamonds, Seven Spades],
#    [Ace Diamonds, Seven Clubs],
#    [Ace Diamonds, Seven Hearts],
#    [Ace Spades, Six Clubs],
#    [Ace Spades, Six Hearts],
#    [Ace Spades, Six Diamonds],
#    [Ace Clubs, Six Spades],
#    [Ace Clubs, Six Hearts],
#    [Ace Clubs, Six Diamonds],
#    [Ace Hearts, Six Spades],
#    [Ace Hearts, Six Clubs],
#    [Ace Hearts, Six Diamonds],
#    [Ace Diamonds, Six Spades],
#    [Ace Diamonds, Six Clubs],
#    [Ace Diamonds, Six Hearts],
#    [Ace Spades, Five Clubs],
#    [Ace Spades, Five Hearts],
#    [Ace Spades, Five Diamonds],
#    [Ace Clubs, Five Spades],
#    [Ace Clubs, Five Hearts],
#    [Ace Clubs, Five Diamonds],
#    [Ace Hearts, Five Spades],
#    [Ace Hearts, Five Clubs],
#    [Ace Hearts, Five Diamonds],
#    [Ace Diamonds, Five Spades],
#    [Ace Diamonds, Five Clubs],
#    [Ace Diamonds, Five Hearts],
#    [Ace Spades, Four Clubs],
#    [Ace Spades, Four Hearts],
#    [Ace Spades, Four Diamonds],
#    [Ace Clubs, Four Spades],
#    [Ace Clubs, Four Hearts],
#    [Ace Clubs, Four Diamonds],
#    [Ace Hearts, Four Spades],
#    [Ace Hearts, Four Clubs],
#    [Ace Hearts, Four Diamonds],
#    [Ace Diamonds, Four Spades],
#    [Ace Diamonds, Four Clubs],
#    [Ace Diamonds, Four Hearts],
#    [Ace Spades, Three Clubs],
#    [Ace Spades, Three Hearts],
#    [Ace Spades, Three Diamonds],
#    [Ace Clubs, Three Spades],
#    [Ace Clubs, Three Hearts],
#    [Ace Clubs, Three Diamonds],
#    [Ace Hearts, Three Spades],
#    [Ace Hearts, Three Clubs],
#    [Ace Hearts, Three Diamonds],
#    [Ace Diamonds, Three Spades],
#    [Ace Diamonds, Three Clubs],
#    [Ace Diamonds, Three Hearts],
#    [Ace Spades, Two Clubs],
#    [Ace Spades, Two Hearts],
#    [Ace Spades, Two Diamonds],
#    [Ace Clubs, Two Spades],
#    [Ace Clubs, Two Hearts],
#    [Ace Clubs, Two Diamonds],
#    [Ace Hearts, Two Spades],
#    [Ace Hearts, Two Clubs],
#    [Ace Hearts, Two Diamonds],
#    [Ace Diamonds, Two Spades],
#    [Ace Diamonds, Two Clubs],
#    [Ace Diamonds, Two Hearts],
#    [King Spades, Queen Clubs],
#    [King Spades, Queen Hearts],
#    [King Spades, Queen Diamonds],
#    [King Clubs, Queen Spades],
#    [King Clubs, Queen Hearts],
#    [King Clubs, Queen Diamonds],
#    [King Hearts, Queen Spades],
#    [King Hearts, Queen Clubs],
#    [King Hearts, Queen Diamonds],
#    [King Diamonds, Queen Spades],
#    [King Diamonds, Queen Clubs],
#    [King Diamonds, Queen Hearts],
#    [King Spades, Jack Clubs],
#    [King Spades, Jack Hearts],
#    [King Spades, Jack Diamonds],
#    [King Clubs, Jack Spades],
#    [King Clubs, Jack Hearts],
#    [King Clubs, Jack Diamonds],
#    [King Hearts, Jack Spades],
#    [King Hearts, Jack Clubs],
#    [King Hearts, Jack Diamonds],
#    [King Diamonds, Jack Spades],
#    [King Diamonds, Jack Clubs],
#    [King Diamonds, Jack Hearts],
#    [King Spades, Ten Clubs],
#    [King Spades, Ten Hearts],
#    [King Spades, Ten Diamonds],
#    [King Clubs, Ten Spades],
#    [King Clubs, Ten Hearts],
#    [King Clubs, Ten Diamonds],
#    [King Hearts, Ten Spades],
#    [King Hearts, Ten Clubs],
#    [King Hearts, Ten Diamonds],
#    [King Diamonds, Ten Spades],
#    [King Diamonds, Ten Clubs],
#    [King Diamonds, Ten Hearts],
#    [King Spades, Nine Clubs],
#    [King Spades, Nine Hearts],
#    [King Spades, Nine Diamonds],
#    [King Clubs, Nine Spades],
#    [King Clubs, Nine Hearts],
#    [King Clubs, Nine Diamonds],
#    [King Hearts, Nine Spades],
#    [King Hearts, Nine Clubs],
#    [King Hearts, Nine Diamonds],
#    [King Diamonds, Nine Spades],
#    [King Diamonds, Nine Clubs],
#    [King Diamonds, Nine Hearts],
#    [King Spades, Eight Clubs],
#    [King Spades, Eight Hearts],
#    [King Spades, Eight Diamonds],
#    [King Clubs, Eight Spades],
#    [King Clubs, Eight Hearts],
#    [King Clubs, Eight Diamonds],
#    [King Hearts, Eight Spades],
#    [King Hearts, Eight Clubs],
#    [King Hearts, Eight Diamonds],
#    [King Diamonds, Eight Spades],
#    [King Diamonds, Eight Clubs],
#    [King Diamonds, Eight Hearts],
#    [King Spades, Seven Clubs],
#    [King Spades, Seven Hearts],
#    [King Spades, Seven Diamonds],
#    [King Clubs, Seven Spades],
#    [King Clubs, Seven Hearts],
#    [King Clubs, Seven Diamonds],
#    [King Hearts, Seven Spades],
#    [King Hearts, Seven Clubs],
#    [King Hearts, Seven Diamonds],
#    [King Diamonds, Seven Spades],
#    [King Diamonds, Seven Clubs],
#    [King Diamonds, Seven Hearts],
#    [King Spades, Six Clubs],
#    [King Spades, Six Hearts],
#    [King Spades, Six Diamonds],
#    [King Clubs, Six Spades],
#    [King Clubs, Six Hearts],
#    [King Clubs, Six Diamonds],
#    [King Hearts, Six Spades],
#    [King Hearts, Six Clubs],
#    [King Hearts, Six Diamonds],
#    [King Diamonds, Six Spades],
#    [King Diamonds, Six Clubs],
#    [King Diamonds, Six Hearts],
#    [King Spades, Five Clubs],
#    [King Spades, Five Hearts],
#    [King Spades, Five Diamonds],
#    [King Clubs, Five Spades],
#    [King Clubs, Five Hearts],
#    [King Clubs, Five Diamonds],
#    [King Hearts, Five Spades],
#    [King Hearts, Five Clubs],
#    [King Hearts, Five Diamonds],
#    [King Diamonds, Five Spades],
#    [King Diamonds, Five Clubs],
#    [King Diamonds, Five Hearts],
#    [King Spades, Four Clubs],
#    [King Spades, Four Hearts],
#    [King Spades, Four Diamonds],
#    [King Clubs, Four Spades],
#    [King Clubs, Four Hearts],
#    [King Clubs, Four Diamonds],
#    [King Hearts, Four Spades],
#    [King Hearts, Four Clubs],
#    [King Hearts, Four Diamonds],
#    [King Diamonds, Four Spades],
#    [King Diamonds, Four Clubs],
#    [King Diamonds, Four Hearts],
#    [King Spades, Three Clubs],
#    [King Spades, Three Hearts],
#    [King Spades, Three Diamonds],
#    [King Clubs, Three Spades],
#    [King Clubs, Three Hearts],
#    [King Clubs, Three Diamonds],
#    [King Hearts, Three Spades],
#    [King Hearts, Three Clubs],
#    [King Hearts, Three Diamonds],
#    [King Diamonds, Three Spades],
#    [King Diamonds, Three Clubs],
#    [King Diamonds, Three Hearts],
#    [King Spades, Two Clubs],
#    [King Spades, Two Hearts],
#    [King Spades, Two Diamonds],
#    [King Clubs, Two Spades],
#    [King Clubs, Two Hearts],
#    [King Clubs, Two Diamonds],
#    [King Hearts, Two Spades],
#    [King Hearts, Two Clubs],
#    [King Hearts, Two Diamonds],
#    [King Diamonds, Two Spades],
#    [King Diamonds, Two Clubs],
#    [King Diamonds, Two Hearts],
#    [Five Spades, Four Clubs],
#    [Five Spades, Four Hearts],
#    [Five Spades, Four Diamonds],
#    [Five Clubs, Four Spades],
#    [Five Clubs, Four Hearts],
#    [Five Clubs, Four Diamonds],
#    [Five Hearts, Four Spades],
#    [Five Hearts, Four Clubs],
#    [Five Hearts, Four Diamonds],
#    [Five Diamonds, Four Spades],
#    [Five Diamonds, Four Clubs],
#    [Five Diamonds, Four Hearts],
#    [Five Spades, Three Clubs],
#    [Five Spades, Three Hearts],
#    [Five Spades, Three Diamonds],
#    [Five Clubs, Three Spades],
#    [Five Clubs, Three Hearts],
#    [Five Clubs, Three Diamonds],
#    [Five Hearts, Three Spades],
#    [Five Hearts, Three Clubs],
#    [Five Hearts, Three Diamonds],
#    [Five Diamonds, Three Spades],
#    [Five Diamonds, Three Clubs],
#    [Five Diamonds, Three Hearts],
#    [Four Spades, Three Clubs],
#    [Four Spades, Three Hearts],
#    [Four Spades, Three Diamonds],
#    [Four Clubs, Three Spades],
#    [Four Clubs, Three Hearts],
#    [Four Clubs, Three Diamonds],
#    [Four Hearts, Three Spades],
#    [Four Hearts, Three Clubs],
#    [Four Hearts, Three Diamonds],
#    [Four Diamonds, Three Spades],
#    [Four Diamonds, Three Clubs],
#    [Four Diamonds, Three Hearts],
#    [Queen Spades, Jack Clubs],
#    [Queen Spades, Jack Hearts],
#    [Queen Spades, Jack Diamonds],
#    [Queen Clubs, Jack Spades],
#    [Queen Clubs, Jack Hearts],
#    [Queen Clubs, Jack Diamonds],
#    [Queen Hearts, Jack Spades],
#    [Queen Hearts, Jack Clubs],
#    [Queen Hearts, Jack Diamonds],
#    [Queen Diamonds, Jack Spades],
#    [Queen Diamonds, Jack Clubs],
#    [Queen Diamonds, Jack Hearts],
#    [Queen Spades, Ten Clubs],
#    [Queen Spades, Ten Hearts],
#    [Queen Spades, Ten Diamonds],
#    [Queen Clubs, Ten Spades],
#    [Queen Clubs, Ten Hearts],
#    [Queen Clubs, Ten Diamonds],
#    [Queen Hearts, Ten Spades],
#    [Queen Hearts, Ten Clubs],
#    [Queen Hearts, Ten Diamonds],
#    [Queen Diamonds, Ten Spades],
#    [Queen Diamonds, Ten Clubs],
#    [Queen Diamonds, Ten Hearts],
#    [Queen Spades, Nine Clubs],
#    [Queen Spades, Nine Hearts],
#    [Queen Spades, Nine Diamonds],
#    [Queen Clubs, Nine Spades],
#    [Queen Clubs, Nine Hearts],
#    [Queen Clubs, Nine Diamonds],
#    [Queen Hearts, Nine Spades],
#    [Queen Hearts, Nine Clubs],
#    [Queen Hearts, Nine Diamonds],
#    [Queen Diamonds, Nine Spades],
#    [Queen Diamonds, Nine Clubs],
#    [Queen Diamonds, Nine Hearts],
#    [Queen Spades, Eight Clubs],
#    [Queen Spades, Eight Hearts],
#    [Queen Spades, Eight Diamonds],
#    [Queen Clubs, Eight Spades],
#    [Queen Clubs, Eight Hearts],
#    [Queen Clubs, Eight Diamonds],
#    [Queen Hearts, Eight Spades],
#    [Queen Hearts, Eight Clubs],
#    [Queen Hearts, Eight Diamonds],
#    [Queen Diamonds, Eight Spades],
#    [Queen Diamonds, Eight Clubs],
#    [Queen Diamonds, Eight Hearts],
#    [Queen Spades, Seven Clubs],
#    [Queen Spades, Seven Hearts],
#    [Queen Spades, Seven Diamonds],
#    [Queen Clubs, Seven Spades],
#    [Queen Clubs, Seven Hearts],
#    [Queen Clubs, Seven Diamonds],
#    [Queen Hearts, Seven Spades],
#    [Queen Hearts, Seven Clubs],
#    [Queen Hearts, Seven Diamonds],
#    [Queen Diamonds, Seven Spades],
#    [Queen Diamonds, Seven Clubs],
#    [Queen Diamonds, Seven Hearts],
#    [Queen Spades, Six Clubs],
#    [Queen Spades, Six Hearts],
#    [Queen Spades, Six Diamonds],
#    [Queen Clubs, Six Spades],
#    [Queen Clubs, Six Hearts],
#    [Queen Clubs, Six Diamonds],
#    [Queen Hearts, Six Spades],
#    [Queen Hearts, Six Clubs],
#    [Queen Hearts, Six Diamonds],
#    [Queen Diamonds, Six Spades],
#    [Queen Diamonds, Six Clubs],
#    [Queen Diamonds, Six Hearts],
#    [Queen Spades, Five Clubs],
#    [Queen Spades, Five Hearts],
#    [Queen Spades, Five Diamonds],
#    [Queen Clubs, Five Spades],
#    [Queen Clubs, Five Hearts],
#    [Queen Clubs, Five Diamonds],
#    [Queen Hearts, Five Spades],
#    [Queen Hearts, Five Clubs],
#    [Queen Hearts, Five Diamonds],
#    [Queen Diamonds, Five Spades],
#    [Queen Diamonds, Five Clubs],
#    [Queen Diamonds, Five Hearts],
#    [Queen Spades, Four Clubs],
#    [Queen Spades, Four Hearts],
#    [Queen Spades, Four Diamonds],
#    [Queen Clubs, Four Spades],
#    [Queen Clubs, Four Hearts],
#    [Queen Clubs, Four Diamonds],
#    [Queen Hearts, Four Spades],
#    [Queen Hearts, Four Clubs],
#    [Queen Hearts, Four Diamonds],
#    [Queen Diamonds, Four Spades],
#    [Queen Diamonds, Four Clubs],
#    [Queen Diamonds, Four Hearts],
#    [Seven Spades, Six Clubs],
#    [Seven Spades, Six Hearts],
#    [Seven Spades, Six Diamonds],
#    [Seven Clubs, Six Spades],
#    [Seven Clubs, Six Hearts],
#    [Seven Clubs, Six Diamonds],
#    [Seven Hearts, Six Spades],
#    [Seven Hearts, Six Clubs],
#    [Seven Hearts, Six Diamonds],
#    [Seven Diamonds, Six Spades],
#    [Seven Diamonds, Six Clubs],
#    [Seven Diamonds, Six Hearts],
#    [Seven Spades, Five Clubs],
#    [Seven Spades, Five Hearts],
#    [Seven Spades, Five Diamonds],
#    [Seven Clubs, Five Spades],
#    [Seven Clubs, Five Hearts],
#    [Seven Clubs, Five Diamonds],
#    [Seven Hearts, Five Spades],
#    [Seven Hearts, Five Clubs],
#    [Seven Hearts, Five Diamonds],
#    [Seven Diamonds, Five Spades],
#    [Seven Diamonds, Five Clubs],
#    [Seven Diamonds, Five Hearts],
#    [Seven Spades, Four Clubs],
#    [Seven Spades, Four Hearts],
#    [Seven Spades, Four Diamonds],
#    [Seven Clubs, Four Spades],
#    [Seven Clubs, Four Hearts],
#    [Seven Clubs, Four Diamonds],
#    [Seven Hearts, Four Spades],
#    [Seven Hearts, Four Clubs],
#    [Seven Hearts, Four Diamonds],
#    [Seven Diamonds, Four Spades],
#    [Seven Diamonds, Four Clubs],
#    [Seven Diamonds, Four Hearts],
#    [Six Spades, Five Clubs],
#    [Six Spades, Five Hearts],
#    [Six Spades, Five Diamonds],
#    [Six Clubs, Five Spades],
#    [Six Clubs, Five Hearts],
#    [Six Clubs, Five Diamonds],
#    [Six Hearts, Five Spades],
#    [Six Hearts, Five Clubs],
#    [Six Hearts, Five Diamonds],
#    [Six Diamonds, Five Spades],
#    [Six Diamonds, Five Clubs],
#    [Six Diamonds, Five Hearts],
#    [Six Spades, Four Clubs],
#    [Six Spades, Four Hearts],
#    [Six Spades, Four Diamonds],
#    [Six Clubs, Four Spades],
#    [Six Clubs, Four Hearts],
#    [Six Clubs, Four Diamonds],
#    [Six Hearts, Four Spades],
#    [Six Hearts, Four Clubs],
#    [Six Hearts, Four Diamonds],
#    [Six Diamonds, Four Spades],
#    [Six Diamonds, Four Clubs],
#    [Six Diamonds, Four Hearts],
#    [Jack Spades, Ten Clubs],
#    [Jack Spades, Ten Hearts],
#    [Jack Spades, Ten Diamonds],
#    [Jack Clubs, Ten Spades],
#    [Jack Clubs, Ten Hearts],
#    [Jack Clubs, Ten Diamonds],
#    [Jack Hearts, Ten Spades],
#    [Jack Hearts, Ten Clubs],
#    [Jack Hearts, Ten Diamonds],
#    [Jack Diamonds, Ten Spades],
#    [Jack Diamonds, Ten Clubs],
#    [Jack Diamonds, Ten Hearts],
#    [Jack Spades, Nine Clubs],
#    [Jack Spades, Nine Hearts],
#    [Jack Spades, Nine Diamonds],
#    [Jack Clubs, Nine Spades],
#    [Jack Clubs, Nine Hearts],
#    [Jack Clubs, Nine Diamonds],
#    [Jack Hearts, Nine Spades],
#    [Jack Hearts, Nine Clubs],
#    [Jack Hearts, Nine Diamonds],
#    [Jack Diamonds, Nine Spades],
#    [Jack Diamonds, Nine Clubs],
#    [Jack Diamonds, Nine Hearts],
#    [Jack Spades, Eight Clubs],
#    [Jack Spades, Eight Hearts],
#    [Jack Spades, Eight Diamonds],
#    [Jack Clubs, Eight Spades],
#    [Jack Clubs, Eight Hearts],
#    [Jack Clubs, Eight Diamonds],
#    [Jack Hearts, Eight Spades],
#    [Jack Hearts, Eight Clubs],
#    [Jack Hearts, Eight Diamonds],
#    [Jack Diamonds, Eight Spades],
#    [Jack Diamonds, Eight Clubs],
#    [Jack Diamonds, Eight Hearts],
#    [Jack Spades, Seven Clubs],
#    [Jack Spades, Seven Hearts],
#    [Jack Spades, Seven Diamonds],
#    [Jack Clubs, Seven Spades],
#    [Jack Clubs, Seven Hearts],
#    [Jack Clubs, Seven Diamonds],
#    [Jack Hearts, Seven Spades],
#    [Jack Hearts, Seven Clubs],
#    [Jack Hearts, Seven Diamonds],
#    [Jack Diamonds, Seven Spades],
#    [Jack Diamonds, Seven Clubs],
#    [Jack Diamonds, Seven Hearts],
#    [Jack Spades, Six Clubs],
#    [Jack Spades, Six Hearts],
#    [Jack Spades, Six Diamonds],
#    [Jack Clubs, Six Spades],
#    [Jack Clubs, Six Hearts],
#    [Jack Clubs, Six Diamonds],
#    [Jack Hearts, Six Spades],
#    [Jack Hearts, Six Clubs],
#    [Jack Hearts, Six Diamonds],
#    [Jack Diamonds, Six Spades],
#    [Jack Diamonds, Six Clubs],
#    [Jack Diamonds, Six Hearts],
#    [Jack Spades, Five Clubs],
#    [Jack Spades, Five Hearts],
#    [Jack Spades, Five Diamonds],
#    [Jack Clubs, Five Spades],
#    [Jack Clubs, Five Hearts],
#    [Jack Clubs, Five Diamonds],
#    [Jack Hearts, Five Spades],
#    [Jack Hearts, Five Clubs],
#    [Jack Hearts, Five Diamonds],
#    [Jack Diamonds, Five Spades],
#    [Jack Diamonds, Five Clubs],
#    [Jack Diamonds, Five Hearts],
#    [Ten Spades, Nine Clubs],
#    [Ten Spades, Nine Hearts],
#    [Ten Spades, Nine Diamonds],
#    [Ten Clubs, Nine Spades],
#    [Ten Clubs, Nine Hearts],
#    [Ten Clubs, Nine Diamonds],
#    [Ten Hearts, Nine Spades],
#    [Ten Hearts, Nine Clubs],
#    [Ten Hearts, Nine Diamonds],
#    [Ten Diamonds, Nine Spades],
#    [Ten Diamonds, Nine Clubs],
#    [Ten Diamonds, Nine Hearts],
#    [Ten Spades, Eight Clubs],
#    [Ten Spades, Eight Hearts],
#    [Ten Spades, Eight Diamonds],
#    [Ten Clubs, Eight Spades],
#    [Ten Clubs, Eight Hearts],
#    [Ten Clubs, Eight Diamonds],
#    [Ten Hearts, Eight Spades],
#    [Ten Hearts, Eight Clubs],
#    [Ten Hearts, Eight Diamonds],
#    [Ten Diamonds, Eight Spades],
#    [Ten Diamonds, Eight Clubs],
#    [Ten Diamonds, Eight Hearts],
#    [Ten Spades, Seven Clubs],
#    [Ten Spades, Seven Hearts],
#    [Ten Spades, Seven Diamonds],
#    [Ten Clubs, Seven Spades],
#    [Ten Clubs, Seven Hearts],
#    [Ten Clubs, Seven Diamonds],
#    [Ten Hearts, Seven Spades],
#    [Ten Hearts, Seven Clubs],
#    [Ten Hearts, Seven Diamonds],
#    [Ten Diamonds, Seven Spades],
#    [Ten Diamonds, Seven Clubs],
#    [Ten Diamonds, Seven Hearts],
#    [Ten Spades, Six Clubs],
#    [Ten Spades, Six Hearts],
#    [Ten Spades, Six Diamonds],
#    [Ten Clubs, Six Spades],
#    [Ten Clubs, Six Hearts],
#    [Ten Clubs, Six Diamonds],
#    [Ten Hearts, Six Spades],
#    [Ten Hearts, Six Clubs],
#    [Ten Hearts, Six Diamonds],
#    [Ten Diamonds, Six Spades],
#    [Ten Diamonds, Six Clubs],
#    [Ten Diamonds, Six Hearts],
#    [Ten Spades, Five Clubs],
#    [Ten Spades, Five Hearts],
#    [Ten Spades, Five Diamonds],
#    [Ten Clubs, Five Spades],
#    [Ten Clubs, Five Hearts],
#    [Ten Clubs, Five Diamonds],
#    [Ten Hearts, Five Spades],
#    [Ten Hearts, Five Clubs],
#    [Ten Hearts, Five Diamonds],
#    [Ten Diamonds, Five Spades],
#    [Ten Diamonds, Five Clubs],
#    [Ten Diamonds, Five Hearts],
#    [Nine Spades, Eight Clubs],
#    [Nine Spades, Eight Hearts],
#    [Nine Spades, Eight Diamonds],
#    [Nine Clubs, Eight Spades],
#    [Nine Clubs, Eight Hearts],
#    [Nine Clubs, Eight Diamonds],
#    [Nine Hearts, Eight Spades],
#    [Nine Hearts, Eight Clubs],
#    [Nine Hearts, Eight Diamonds],
#    [Nine Diamonds, Eight Spades],
#    ...],
#   15.395),
#  ([[Ace Spades, Ace Clubs]], 84.605)]
